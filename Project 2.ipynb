# %% [markdown]
# ### Storytelling Data Visualization on Exchange Rates
# there are two types of data visualization:
#  * Exploratory data visualization: we create graphs for ourselves to better understand and explore data.
#  * Explanatory data visualization: we create graphs for others to inform, make a point, or tell a story.
#
# Throughout the Project, we focused on explanatory data visualization and learned the following:
#
# * How to use information design principles (familiarity and maximizing the data-ink ratio) to create better graphs for an audience.
# * About the elements of a story and how to create storytelling data visualizations using Matplotlib.
# * How to guide the audience's attention with pre-attentive attributes.
# * How to use Matplotlib built-in styles — with a case study on the FiveThirtyEight style.

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

exchange_rates=pd.read_csv("euro-daily-hist_1999_2022.csv")

# %%
exchange_rates.shape
# Out:
# (6456, 41)

# %%
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-12-15               1.6324           1.9558            5.4085
# 1   2023-12-14               1.6288           1.9558            5.3349
# 2   2023-12-13               1.6452           1.9558            5.3609
# 3   2023-12-12               1.6398           1.9558            5.3327
# 4   2023-12-11                1.642           1.9558            5.3169
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4653         0.9488                   7.7812              NaN
# 1             1.4677          0.949                   7.7866              NaN
# 2             1.4644         0.9452                   7.7426              NaN
# 3             1.4656         0.9443                   7.7447              NaN
# 4             1.4609         0.9478                   7.7206              NaN
#
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6456 entries, 0 to 6455
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6456 non-null   object
#  1   [Australian dollar ]      6456 non-null   object
#  2   [Bulgarian lev ]          6054 non-null   object
#  3   [Brazilian real ]         6188 non-null   object
#  4   [Canadian dollar ]        6456 non-null   object
#  5   [Swiss franc ]            6456 non-null   object
#  6   [Chinese yuan renminbi ]  6188 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6456 non-null   object
#  9   [Danish krone ]           6456 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6456 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
exchange_rates.rename(columns={'[US dollar ]':'US_dollar','Period\\Unit:':'Time'},inplace=True)

exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])

exchange_rates.sort_values('Time', inplace=True)

exchange_rates.head()
# Out:
#            Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6455 1999-01-04               1.9100              NaN               NaN
# 6454 1999-01-05               1.8944              NaN               NaN
# 6453 1999-01-06               1.8820              NaN               NaN
# 6452 1999-01-07               1.8474              NaN               NaN
# 6451 1999-01-08               1.8406              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6455             1.8004         1.6168                      NaN
# 6454             1.7965         1.6123                      NaN
# 6453             1.7711         1.6116                      NaN
# 6452             1.7602         1.6165                      NaN
# 6451             1.7643         1.6138                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
euro_to_dollar = exchange_rates[['Time','US_dollar']].copy()
euro_to_dollar['US_dollar'].value_counts() #62 '-' characters(may be holidays)
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.0888     7
# 1.0868     7
#           ..
# 1.4304     1
# 1.4350     1
# 1.4442     1
# 1.4389     1
# 1.0804     1
# Name: US_dollar, Length: 3769, dtype: int64

# %%
euro_to_dollar=euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6394 entries, 6455 to 0
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       6394 non-null   datetime64[ns]
#  1   US_dollar  6394 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 149.9 KB

# %% [markdown]
# # Rolling mean

# %%
import matplotlib.pyplot as plt

plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %% [markdown]
# If we look at the line's shape, we see many small wiggles — rather than seeing a smooth line. The wiggles, however, have meaning: : they are the visual representation of the daily variation in the exchange rate. The rate goes up and down, up and down again, day to day. The rate only shows clear upward or downward trends in the longer run (months or years).
#
# Depending on our goals, we may not want to show that daily variation on our graph. If we want to hide it and show only the long-term trends, we can use the rolling mean (also known as the moving average).

# %%
values = pd.DataFrame()
values["daily_values"] = pd.Series(range(1,20,2))
values
# Out:
#    daily_values
# 0             1
# 1             3
# 2             5
# 3             7
# 4             9
# 5            11
# 6            13
# 7            15
# 8            17
# 9            19

# %%
values["rolling_mean_2"] = values["daily_values"].rolling(2).mean()
values
# Out:
#    daily_values  rolling_mean_2
# 0             1             NaN
# 1             3             2.0
# 2             5             4.0
# 3             7             6.0
# 4             9             8.0
# 5            11            10.0
# 6            13            12.0
# 7            15            14.0
# 8            17            16.0
# 9            19            18.0

# %%
values["rolling_mean_3"] = values["daily_values"].rolling(3).mean()
values["rolling_mean_5"] = values["daily_values"].rolling(5).mean()
values
# Out:
#    daily_values  rolling_mean_2  rolling_mean_3  rolling_mean_5
# 0             1             NaN             NaN             NaN
# 1             3             2.0             NaN             NaN
# 2             5             4.0             3.0             NaN
# 3             7             6.0             5.0             NaN
# 4             9             8.0             7.0             5.0
# 5            11            10.0             9.0             7.0
# 6            13            12.0            11.0             9.0
# 7            15            14.0            13.0            11.0
# 8            17            16.0            15.0            13.0
# 9            19            18.0            17.0            15.0

# %%
plt.figure(figsize=(16,13))

plt.subplot(3,2,1)
plt.plot(euro_to_dollar["Time"],euro_to_dollar["US_dollar"])
plt.title('Original Values',weight='bold')
plt.ylim(0.8,1.7)

for i, rolling_mean in zip([2,3,4,5,6,],[7,30,50,100,365]):
    plt.subplot(3,2,i)
    plt.plot(euro_to_dollar['Time'],euro_to_dollar['US_dollar'].rolling(rolling_mean).mean())
    plt.title('Rolling Window:' + str(rolling_mean),weight='bold')
    plt.ylim(0.8,1.7)

plt.tight_layout() # Auto_adjust the padding between the subplots
plt.show()

# %% [markdown]
# ### Coming up with idea
# here are few story ideas for our data
#
#  * We show how the euro_dollar rate has changed during the covid_19 pandemic.We can show the 2020 data and the 2016_2019 data      as a baseline we can use line plot.
#
#  * We show how the euro_dollar rate changed during the 2007_2008 financial crises. We can also show the data 2006 and 2009
#    for comparison we can use line plot
#
#  * We show comparatively how the euro_dollar rate changed under the last three US presidents (George W.Bush(2001-2009).Barak      Obama(2000_2017) and Donald Trump(2017_2021)).We can use a line plot

# %%
euro_to_dollar["rolling_mean"]=euro_to_dollar['US_dollar'].rolling(30).mean()
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 6455 1999-01-04     1.1789           NaN
# 6454 1999-01-05     1.1790           NaN
# 6453 1999-01-06     1.1743           NaN
# 6452 1999-01-07     1.1632           NaN
# 6451 1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 4    2023-12-11     1.0757      1.080143
# 3    2023-12-12     1.0804      1.080760
# 2    2023-12-13     1.0787      1.081593
# 1    2023-12-14     1.0919      1.082453
# 0    2023-12-15     1.0946      1.083267
#
# [6394 rows x 3 columns]

# %% [markdown]
# # Storytelling data visualization.
# Financial Crisis 2007_2008

# %%
financial_crisis = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >=2006) & (euro_to_dollar['Time'].dt.year <=2009)]

financial_crisis_7_8 = euro_to_dollar.copy()[(euro_to_dollar.Time.dt.year >=2007) & (euro_to_dollar.Time.dt.year <=2008)]

# %%
import matplotlib.style as style
style.use('fivethirtyeight')

### Adding the plot
fig,ax=plt.subplots(figsize=(8,3))
ax.plot(financial_crisis['Time'],financial_crisis['rolling_mean'],linewidth=2,color='#F07725')

### Highlighting the 2007_2008 period
ax.plot(financial_crisis_7_8['Time'],financial_crisis_7_8['rolling_mean'],linewidth=2,color='#00148C')

# print(ax.set_xticklabels(["2006","2007","2008","2009","2010"],alpha=0.3))

ax.set_xticklabels([])
x = 0.02
for year in ["2006","2007","2008","2009","2010"]:
    ax.text(x,-0.08,year,alpha=0.5,fontsize=11,transform=plt.gca().transAxes)
    x+= 0.22888
    
# print(plt.yticks())
ax.set_yticklabels([])

y = 0.07
for rate in ['1.2','1,3','1.4','1.5']:
    ax.text(-.04,y,rate,alpha=0.5,fontsize=11,transform=plt.gca().transAxes)
    y += 0.2333

## Adding a title and a subtitle
ax.text(-.05,1.2,"Euro_usd rate peaked at 1.59 during 2007_2008's financial crisis",weight='bold',transform=plt.gca().transAxes)
ax.text(-.05,1.1,"Euro_usd exchanged rate between 2006_2010 ",size=12,transform=plt.gca().transAxes)

### Adiing a signature
ax.axvspan(xmin=pd.to_datetime("2008-4-1"),xmax=pd.to_datetime("2008-9-1"),ymin=0.09,alpha=0.3,color="grey")

plt.show()

# %% [markdown]
# This graph tracks the Euro to US dollar exchange rate from 2006 to 2010, emphasizing the financial crisis period of 2007-2008. Starting in 2006, the Euro strengthens against the dollar, as indicated by the orange line that turns blue as the rate climbs. It reaches its peak at 1.59 during the crisis—marked by the shaded area—then sharply drops, reflecting the crisis's high point. Post-crisis, the rate stabilizes and begins a recovery, as shown by the line turning orange again, suggesting some economic recovery or stabilization by 2010.

# %% [markdown]
#  # Covid19

# %%
corona_crisis_20=euro_to_dollar.loc[(euro_to_dollar['Time']>="2020-01-01")&(euro_to_dollar['Time']<="2020-12-31")]

corona_crisis=euro_to_dollar.loc[(euro_to_dollar['Time']>="2016-01-01")&(euro_to_dollar['Time']<="2019-12-31")]

# %%
import matplotlib.style as style
style.use('fivethirtyeight')

### Adding the plot
fig,ax=plt.subplots(figsize=(9,3))
ax.plot(corona_crisis['Time'],corona_crisis['rolling_mean'],linewidth=2,color='#FF91CB')

### Highlighting the 2020 period
ax.plot(corona_crisis_20['Time'],corona_crisis_20['rolling_mean'],linewidth=3,color='#00148C')

# print(ax.set_xticklabels(["2016","2017","2018","2019","2020","2021"],alpha=0.5))
ax.set_xticklabels([])
x = 0.02
for year in ["2016","2017","2018","2019","2020"]:
    ax.text(x,-0.08,year,alpha=0.5,fontsize=11,transform=plt.gca().transAxes)
    x+=0.22888
    
 # print(plt.yticks())
ax.set_yticklabels([])

y = 0.02
for rate in ['1.05','1,10','1.15','1.20']:
    ax.text(-.04,y,rate,alpha=0.5,fontsize=11,transform=plt.gca().transAxes)
    y += 0.248

## Adding a title and a subtitle
ax.text(-.05,1.2,"Euro_usd rate peaked at 1.22 during 2020's COVID19 crisis",weight='bold',transform=plt.gca().transAxes)
ax.text(-.05,1.1,"Euro_usd exchanged rate between 2016 and 2020 ",size=12,transform=plt.gca().transAxes)

plt.show()

# %% [markdown]
# This graph illustrates the fluctuation in the exchange rate between the Euro and the US dollar over a span from 2016 to 2020. It shows a general downward trend in the value of the Euro against the dollar until the end of 2019. However, in 2020, there is a notable surge where the rate peaks at 1.22 during the COVID-19 crisis, as highlighted by the change in the line color from pink to blue. This peak likely reflects the market's reaction to the pandemic's economic impact, where currency values can be influenced by a variety of factors including economic policies, investor sentiment, and global events.

# %% [markdown]
# # The Three US Presidencies Example

# %%
bush_obama_trump = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2001) & (euro_to_dollar['Time'].dt.year < 2021)]

bush = bush_obama_trump.copy()[bush_obama_trump['Time'].dt.year < 2009]

obama = bush_obama_trump.copy()[(bush_obama_trump['Time'].dt.year >=2009) & (bush_obama_trump['Time'].dt.year < 2017)]

trump = bush_obama_trump.copy()[(bush_obama_trump['Time'].dt.year >= 2017) & (bush_obama_trump['Time'].dt.year < 2021)]

# %% [markdown]
#  below you'll notice we use matplotlib's functional approach to build the graph.We use this approach because it offers more flexibility in arranging the subplots:
#  * we first build three of the grapgh on a 2-by-3 grid(this grid should have six subplots,but we only built three; the bottom      row remain empty).
#  * we then build only the bottom grapgh of a 2-by-1 grid(this grid should have two subplots,the top row remain empty).
#  * The two grid are marge, and we end up with three graphs on the top row and one graph on the bottom row.

# %%
### Adding the FiveThirtyEight Style
style.use('fivethirtyeight')

### Adding the subplots
plt.figure(figsize=(14,8))

# Pattern 1
ax1 = plt.subplot(3,3,1) #row, col,index
ax2 = plt.subplot(3,3,2)
ax3 = plt.subplot(3,3,3)

# Pattern 2
ax4 = plt.subplot(3,1,2) #row, col,index

axes = [ax1, ax2, ax3, ax4]

### Change to all the subplots

for ax in axes:
    ax.set_ylim (0.8, 1.7)
    ax.set_yticks([1.0,1.2,1.4,1.6])
    ax.set_yticklabels(['1.0', '1.2', '1.4', '1.6$'], alpha = 0.4)
    
### Ax1 : Bush
ax1.plot(bush['Time'], bush['rolling_mean'], color= '#BF5FFF')
ax1.set_xticklabels(['','2001','','2003','','2005','','2007','','2009'], alpha = 0.3, size = 12)
ax1.text(0.099, 2.45, 'BUSH', fontsize = 18, weight='bold', color='#BF5FFF', transform = plt.gca().transAxes)
ax1.text(0.08, 2.34, '(2001-2009)', weight='bold', alpha=0.3, transform = plt.gca().transAxes)

### Ax2 : Obama
ax2.plot(obama['Time'], obama['rolling_mean'], color= '#ffa500')
ax2.set_xticklabels(['','2009','','2011','','2013','','2015','','2017'], alpha = 0.3)
ax2.text(0.45, 2.45, 'OBAMA', fontsize = 18, weight='bold', color='#ffa500', transform = plt.gca().transAxes)
ax2.text(0.44, 2.34, '(2009-2017)', weight='bold', alpha=0.3, transform = plt.gca().transAxes)

### Ax3 : Trump
ax3.plot(trump['Time'], trump['rolling_mean'], color= '#00b2ee')
ax3.set_xticklabels(['','2017','','20118','','2019','','2020','','2021'], alpha = 0.3)
ax3.text(0.818, 2.45, 'TRUMP', fontsize = 18, weight='bold', color='#00b2ee', transform = plt.gca().transAxes)
ax3.text(0.808, 2.34, '(2017-2021)', weight='bold', alpha=0.3, transform = plt.gca().transAxes)

### Ax4 : Bush-Obama_Trump
ax4.plot(bush['Time'], bush['rolling_mean'], color='#BF5FFF')
ax4.plot(obama['Time'], obama['rolling_mean'], color='#ffa500')
ax4.plot(trump['Time'], trump['rolling_mean'], color='#00b2ee')

ax4.set_xticks([])

### Adding a title and a subtitle
ax1.text(-0.05, 2.8,'EURO-USD rate averaged 1.22 under the last three US presidents', fontsize=20,
        weight='bold', transform = plt.gca().transAxes)
ax1.text(-0.05,2.55, '''EURO-USD exchange rates under Georage W. Bush (2001-2009), Barack Obama (2009-2017), and Donald Trump (2017-2021)
''', fontsize=14, transform=plt.gca().transAxes)

plt.tight_layout()
plt.show()

# %% [markdown]
# # George W. Bush (2001-2009) - Purple Line:
# During the tenure of President Bush, the EURO-USD exchange rate experienced significant volatility. Starting at around parity (1.0) in 2001, the rate increased steadily over the next few years, peaking at just over 1.6 around 2008. This period saw the Euro strengthening against the dollar, meaning it became more expensive in dollars to buy euros. The end of Bush's term was marked by a sharp decline in the rate, coinciding with the global financial crisis of 2007-2008, which significantly affected the USD value.
#
# # Barack Obama (2009-2017) - Orange Line:
# President Obama's term began right after the financial crisis, with the exchange rate already having fallen from its peak. Throughout his presidency, the exchange rate fluctuated mostly between 1.2 and 1.4. While there were ups and downs, the overall trend appears to be a gentle decline, indicating that the dollar was gradually strengthening against the euro or that the euro was weakening against the dollar during this period. By the end of his term, the exchange rate was hovering just above 1.0.
#
# # Donald Trump (2017-2021) - Blue Line:
# Under President Trump, the EURO-USD exchange rate shows a more stable trend, with fewer dramatic changes than in the previous periods. It stayed roughly between 1.1 and 1.2, indicating less volatility and a narrower range of fluctuation. There is a slight upward trend in the later years, suggesting a mild weakening of the USD or strengthening of the euro towards the end of his term.
